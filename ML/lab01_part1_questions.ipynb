# %% [markdown]
# *Credits: materials from this notebook belong to YSDA [Practical DL](https://github.com/yandexdataschool/Practical_DL) course. Special thanks for making them available online.*

# %% [markdown]
# # Lab assignment №1, part 1
#
# This lab assignment consists of several parts. You are supposed to make some transformations, train some models, estimate the quality of the models and explain your results.
#
# Several comments:
# * Don't hesitate to ask questions, it's a good practice.
# * No private/public sharing, please. The copied assignments will be graded with 0 points.
# * Blocks of this lab will be graded separately.

# %% [markdown]
# ## 1. Matrix differentiation

# %% [markdown]
# Since it easy to google every task please please please try to undestand what's going on. The "just answer" thing will be not counted, make sure to present derivation of your solution. It is absolutely OK if you found an answer on web then just exercise in $\LaTeX$ copying it into here.

# %% [markdown]
# Useful links:
# - [Matrix Differentiation (EN)](http://www.atmos.washington.edu/~dennis/MatrixCalculus.pdf)
# - [Матричные вычисления (RU)](http://www.machinelearning.ru/wiki/images/2/2a/Matrix-Gauss.pdf)

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# $$
# y = x^Tx,  \quad x \in \mathbb{R}^N
# $$

# %% [markdown]
# $$
# \frac{dy}{dx} =
# $$

# %% [markdown]
# $y = \sum_{i=1}^{n} x_i^2$
#
# $
# \frac{dy}{dx} = (\frac{\sum_{j=1}^{N} x_j^2}{dx_i})_i = (2x_i)_i = 2x
# $

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# $$ y = tr(AB) \quad A,B \in \mathbb{R}^{N \times N} $$

# %% [markdown]
# $$
# \frac{dy}{dA} =
# $$

# %% [markdown]
# $y = tr(AB) = \sum_{k=1}^{N} \sum_{l=1}^{N} a_{kl}b_{lk}$
#
# $\frac{dy}{dA} =
# (\frac{d(tr(AB))}{da_{ij}})_{ij} =
# (\frac{d\sum_{k=1}^{N} \sum_{l=1}^{N} a_{kl}b_{lk}}{da_{ij}})_{ij} =
# (\frac{d(a_{ij}b_{ji})}{da_{ij}})_{ij} =
# (b_{ji})_{ij} = B^T$

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# $$
# y = x^TAc , \quad A\in \mathbb{R}^{N \times N}, x\in \mathbb{R}^{N}, c\in \mathbb{R}^{N}
# $$

# %% [markdown]
# $$
# \frac{dy}{dx} =
# $$

# %% [markdown]
# $$
# \frac{dy}{dA} =
# $$

# %% [markdown]
# Hint for the latter (one of the ways): use *ex. 2* result and the fact
# $$
# tr(ABC) = tr (CAB)
# $$

# %% [markdown]
# $y = \sum_{1 \leq k,l \leq N} x_k a_{kl} c_l$
#
# $\frac{dy}{dx} =
# (\frac{d\sum_{1 \leq k,l \leq N} x_k a_{kl} c_l}{dx_i})_i =
# (d\sum_{1 \leq l \leq N} a_{il} c_l)_i = Ac$
#
# $\frac{dy}{dA} =
# (\frac{d\sum_{1 \leq k,l \leq N} x_k a_{kl} c_l}{da_{ij}})_{ij} =
# (x_i c_j)_{ij} = xc^T$

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Classic matrix factorization example. Given matrix $X$ you need to find $A$, $S$ to approximate $X$. This can be done by simple gradient descent iteratively alternating $A$ and $S$ updates.
# $$
# J = || X - AS ||_F^2  , \quad A\in \mathbb{R}^{N \times R} , \quad S\in \mathbb{R}^{R \times M}
# $$
# $$
# \frac{dJ}{dS} = ?
# $$
#
# You may use one of the following approaches:

# %% [markdown]
# #### First approach
# Using ex.2 and the fact:
# $$
# || X ||_F^2 = tr(XX^T)
# $$
# it is easy to derive gradients (you can find it in one of the refs).

# %% [markdown]
# $(C)_{ij} = (X-AS)_{ij} = x_{ij}- \sum_{k} a_{ik}s_{kj}$
#
# $(D)_{ij} = ((X-AS)^T)_{ij} = x_{ji}- \sum_{k} a_{jk}s_{ki}$
#
# $
# J = tr(CD) =
# \sum_{i}(\sum_{l} x_{i}^lx^{i}_l - \sum_{k_1} a_{ik_1}s^{k_1l}x^i_l - \sum_{k_2} x_{i}^l a^{ik_2}s_{k_2l} + \sum_{k1, k2}a_{ik_1}s^{k_1l}a^{ik_2}s_{k_2l})
# $
#
# $
# (\frac{dJ}{dS})_{rt} = \frac{dJ}{ds_{rt}} = \frac{d\sum_{i}(\sum_{l} x_{i}^lx^{i}_l - \sum_{k_1} a_{ik_1}s^{k_1l}x^i_l - \sum_{k_2} x_{i}^l a^{ik_2}s_{k_2l} + \sum_{k1, k2}a_{ik_1}s^{k_1l}a^{ik_2}s_{k_2l})}{ds_{rt}} =
# \sum_{i} 2a_{ir}(a_{ik}s_{kt} - x_{it}) = 2A^T(AS-X)$

# %% [markdown]
# #### Second approach
# You can use *slightly different techniques* if they suits you. Take a look at this derivation:
# <img src="grad.png">
#
# (excerpt from [Handbook of blind source separation, Jutten, page 517](https://books.google.ru/books?id=PTbj03bYH6kC&printsec=frontcover&dq=Handbook+of+Blind+Source+Separation&hl=en&sa=X&ved=0ahUKEwi-q_apiJDLAhULvXIKHVXJDWcQ6AEIHDAA#v=onepage&q=Handbook%20of%20Blind%20Source%20Separation&f=false), open for better picture).

# %% [markdown]
# #### Third approach
# And finally we can use chain rule!
# let $ F = AS $
#
# **Find**
# $$
# \frac{dJ}{dF} =
# $$
# and
# $$
# \frac{dF}{dS} =
# $$
# (the shape should be $ NM \times RM )$.
#
# Now it is easy do get desired gradients:
# $$
# \frac{dJ}{dS} =
# $$

# %% [markdown]
# ## 2. kNN questions
# Here come the questions from the assignment0_01. Please, refer to the assignment0_01 to get the context of the questions.

# %% [markdown]
# ### Question 1
#
# Notice the structured patterns in the distance matrix, where some rows or columns are visible brighter. (Note that with the default color scheme black indicates low distances while white indicates high distances.)
#
# - What in the data is the cause behind the distinctly bright rows?
# - What causes the columns?
#
# *Your Answer:*
#
# - it may depend on difference of sample and data
# - Dark columns might occure becouse of abcense of appropriate samples

# %% [markdown]
# ### Question 2
#
# We can also use other distance metrics such as L1 distance.
# For pixel values $p_{ij}^{(k)}$ at location $(i,j)$ of some image $I_k$,
#
# the mean $\mu$ across all pixels over all images is $$\mu=\frac{1}{nhw}\sum_{k=1}^n\sum_{i=1}^{h}\sum_{j=1}^{w}p_{ij}^{(k)}$$
# And the pixel-wise mean $\mu_{ij}$ across all images is
# $$\mu_{ij}=\frac{1}{n}\sum_{k=1}^np_{ij}^{(k)}.$$
# The general standard deviation $\sigma$ and pixel-wise standard deviation $\sigma_{ij}$ is defined similarly.
#
# Which of the following preprocessing steps will not change the performance of a Nearest Neighbor classifier that uses L1 distance? Select all that apply.
# 1. Subtracting the mean $\mu$ ($\tilde{p}_{ij}^{(k)}=p_{ij}^{(k)}-\mu$.)
# 2. Subtracting the per pixel mean $\mu_{ij}$  ($\tilde{p}_{ij}^{(k)}=p_{ij}^{(k)}-\mu_{ij}$.)
# 3. Subtracting the mean $\mu$ and dividing by the standard deviation $\sigma$.
# 4. Subtracting the pixel-wise mean $\mu_{ij}$ and dividing by the pixel-wise standard deviation $\sigma_{ij}$.
# 5. Rotating the coordinate axes of the data.
#
# *Your Answer:* 1,2
#
#
# *Your Explanation:*
#
# 1. The distance is maintained:
#
# $|| \tilde{x}^{(k)} - \tilde{x}^{(l)}|| = \sum_{i}\sum_{j}|(p_{ij}^{(k)}-\mu) - (p_{ij}^{(l)}-\mu)| = \sum_{i}\sum_{j}|p_{ij}^{(k)} - p_{ij}^{(l)}| = ||x^{(k)} - x^{(l)}||$
#
# 2. same as 1.
#
# $|| \tilde{x}^{(k)} - \tilde{x}^{(l)}|| = \sum_{i}\sum_{j}|(p_{ij}^{(k)}-\mu_{ij}) - (p_{ij}^{(l)}-\mu_{ij})| = \sum_{i}\sum_{j}|p_{ij}^{(k)} - p_{ij}^{(l)}| = ||x^{(k)} - x^{(l)}||$

# %% [markdown]
# ## Question 3
#
# Which of the following statements about $k$-Nearest Neighbor ($k$-NN) are true in a classification setting, and for all $k$? Select all that apply.
# 1. The decision boundary (hyperplane between classes in feature space) of the k-NN classifier is linear.
# 2. The training error of a 1-NN will always be lower than that of 5-NN.
# 3. The test error of a 1-NN will always be lower than that of a 5-NN.
# 4. The time needed to classify a test example with the k-NN classifier grows with the size of the training set.
# 5. None of the above.
#
# *Your Answer:* 2,4
#
#
# *Your Explanation:*
# 2.Training error of 1-NN will be equal to 0. Because the nearest neighbour for each training point will be this point itself. In 5-NN model there might happen some mistakes if 5 neares neigbours of point from 1-class will be 4 points from 2-class.
#
# 4.k-NN classifier will need to study every point in training dataset. That's why work time will increase with the size of training set
